# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # PREPROCESSING DATA
# 1. Loading Data
# 2. Cleaning Data
# 3. Case Folding
# 4. Tokenization
# 5. Filtering / Stopword Removal
# 6. Steaming Data

# %% [markdown]
# ## 1. Loading Data

# %%
import pandas as pd
import re
import string
import nltk

# %%
data = pd.read_csv('DATASET_TUTOR_YOUTUBE.csv', sep=';')
data.head()
# Out:
#                        created_at               id_str  \
# 0  Sun Oct 08 23:45:58 +0000 2023  1711166073662525852
# 1  Sun Oct 08 19:26:17 +0000 2023  1711100720181862547
# 2  Sun Oct 08 18:24:09 +0000 2023  1711085086664171913
# 3  Sun Oct 08 20:19:51 +0000 2023  1711114200817275321
# 4  Sun Oct 08 23:32:25 +0000 2023  1711162664553173260
#
#                                            full_text quote_count reply_count  \
# 0  Haaii aku jual netflix 1 bulan sebulan 20k aja...           0           0
# 1  Terlepas apakah yang dilakukan Netflix dengan ...           0           0
# 2  Watched Ice Cold documentary on Netflix, the m...           0           0
# 3                     Ice Cold on Netflix is so good           0           0
# 4  https://t.co/dBHtffcYLr People who have alread...           0           0
#
#   retweet_count favorite_count lang          user_id_str  conversation_id_str  \
# 0             0              0   in  1412947412260319234  1711166073662525852
# 1             0              0   in             44882453  1711100720181862547
# 2             0              2   en            140255354  1711085086664171913
# 3             0              0   en           3070574938  1711114200817275321
# 4             0              0   en           1082040168  1711162664553173260
#
#       username                                          tweet_url
# 0   mixcrowave  https://twitter.com/mixcrowave/status/17111660...
# 1      ddhymaz  https://twitter.com/ddhymaz/status/17111007201...
# 2  ShireenAmir  https://twitter.com/ShireenAmir/status/1711085...
# 3  jennyglozer  https://twitter.com/jennyglozer/status/1711114...
# 4     moi_nisa  https://twitter.com/moi_nisa/status/1711162664...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6386 entries, 0 to 6385
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           6386 non-null   object
#  1   id_str               6386 non-null   object
#  2   full_text            6386 non-null   object
#  3   quote_count          6386 non-null   object
#  4   reply_count          6386 non-null   object
#  5   retweet_count        6386 non-null   object
#  6   favorite_count       6386 non-null   object
#  7   lang                 6386 non-null   object
#  8   user_id_str          6386 non-null   object
#  9   conversation_id_str  6386 non-null   object
#  10  username             6386 non-null   object
#  11  tweet_url            6386 non-null   object
# dtypes: object(12)
# memory usage: 598.8+ KB

# %%
data.drop_duplicates('full_text', keep='first', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5964 entries, 0 to 6385
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           5964 non-null   object
#  1   id_str               5964 non-null   object
#  2   full_text            5964 non-null   object
#  3   quote_count          5964 non-null   object
#  4   reply_count          5964 non-null   object
#  5   retweet_count        5964 non-null   object
#  6   favorite_count       5964 non-null   object
#  7   lang                 5964 non-null   object
#  8   user_id_str          5964 non-null   object
#  9   conversation_id_str  5964 non-null   object
#  10  username             5964 non-null   object
#  11  tweet_url            5964 non-null   object
# dtypes: object(12)
# memory usage: 605.7+ KB

# %%
df = pd.DataFrame(data['full_text'].iloc[0:150])
df.head()
# Out:
#                                            full_text
# 0  Haaii aku jual netflix 1 bulan sebulan 20k aja...
# 1  Terlepas apakah yang dilakukan Netflix dengan ...
# 2  Watched Ice Cold documentary on Netflix, the m...
# 3                     Ice Cold on Netflix is so good
# 4  https://t.co/dBHtffcYLr People who have alread...

# %% [markdown]
# ## 2. Cleaning Data
# - Cleaning URL
# - Cleaning HTML Text
# - Cleaning Emojies
# - Cleaning Number
# - Cleaning Symbols

# %%
def remove_URL(tweet):
  url = re.compile(r'https?://S+|www\.\S+')
  return url.sub(r'', tweet)

def remove_html(tweet):
  html = re.compile(r'<.*?>')
  return html.sub(r'', tweet)

def remove_emoji(tweet):
  emoji_pattern = re.compile("[]"
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
                          "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', tweet)

def remove_numbers(tweet):
  tweet = re.sub(r'\d+', '', tweet)
  return tweet

def remove_symbols(tweet):
  tweet = re.sub(r'[^a-zA-Z0-9\s]', '', tweet)
  return tweet

df['cleaning'] = df['full_text'].apply(lambda x: remove_URL(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_html(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_emoji(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_numbers(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_symbols(x))


df.head()
# Out:
#                                            full_text  \
# 0  Haaii aku jual netflix 1 bulan sebulan 20k aja...
# 1  Terlepas apakah yang dilakukan Netflix dengan ...
# 2  Watched Ice Cold documentary on Netflix, the m...
# 3                     Ice Cold on Netflix is so good
# 4  https://t.co/dBHtffcYLr People who have alread...
#
#                                             cleaning
# 0  Haaii aku jual netflix  bulan sebulan k aja la...
# 1  Terlepas apakah yang dilakukan Netflix dengan ...
# 2  Watched Ice Cold documentary on Netflix the mo...
# 3                     Ice Cold on Netflix is so good
# 4  httpstcodBHtffcYLr People who have already wat...

# %% [markdown]
# ## 3. Case Folding
# - lowercase()

# %%
def case_folding(text):
  if isinstance(text, str):
    lowercase_text = text.lower()
    return lowercase_text
  else:
    return text
df['case_folding'] = df['cleaning'].apply(case_folding)


df.head(30)
# Out:
#                                             full_text  \
# 0   Haaii aku jual netflix 1 bulan sebulan 20k aja...
# 1   Terlepas apakah yang dilakukan Netflix dengan ...
# 2   Watched Ice Cold documentary on Netflix, the m...
# 3                      Ice Cold on Netflix is so good
# 4   https://t.co/dBHtffcYLr People who have alread...
# 5   lebih detailnya lagi setelah netflix #Icecoldn...
# 6   Penjelasan Dokter Ahli Sianida yang tampil dal...
# 7   And that's kid, is how your mother procrastina...
# 8   woi beli netflix dmn yg murce bokap gua mau no...
# 9   pgn beli Netflix lg buat nntn ice cold, soalny...
# 10  Selain “Ice Cold”, Ini Film Dokumenter Netflix...
# 11  🎬 ice cold: murder, coffee and jessica wongso ...
# 12  Tadi maghrib...aku yg lagi nyetrika sambil net...
# 13  Menghukum orang tanpa bukti yang sah. Ingat KA...
# 14  Abis nntn Icecold di netflix. Dulu aku sempet ...
# 15  Reco watch: Ice Cold: Murder, Coffee and Jessi...
# 16  btw cek profil kita ya yg mau nonton One Piece...
# 17  Setelah Netflix Tayangkan Dokumenter 'Ice Cold...
# 18  Adanya film ice cold netflix justru membahayak...
# 19  Udah jenuh banget di RS. Padahal bisa sambil N...
# 5   [lebih, detailnya, lagi, setelah, netflix, ice...
# 6   [penjelasan, dokter, ahli, sianida, yang, tamp...
# 7   [and, thats, kid, is, how, your, mother, procr...
# 8   [woi, beli, netflix, dmn, yg, murce, bokap, gu...
# 9   [pgn, beli, netflix, lg, buat, nntn, ice, cold...
# 10  [selain, ice, cold, ini, film, dokumenter, net...
# 11  [ice, cold, murder, coffee, and, jessica, wong...
# 12  [tadi, maghribaku, yg, lagi, nyetrika, sambil,...
# 13  [menghukum, orang, tanpa, bukti, yang, sah, in...
# 14  [abis, nntn, icecold, di, netflix, dulu, aku, ...
# 15  [reco, watch, ice, cold, murder, coffee, and, ...
# 16  [btw, cek, profil, kita, ya, yg, mau, nonton, ...
# 17  [setelah, netflix, tayangkan, dokumenter, ice,...
# 18  [adanya, film, ice, cold, netflix, justru, mem...
# 19  [udah, jenuh, banget, di, rs, padahal, bisa, s...
# 20  [jangan, lupa, cuci, mata, sebelum, tidur, jes...
# 21  [belum, lama, nonton, dokumenter, ice, cold, t...
# 22  [dari, film, ice, cold, yg, sempat, di, putar,...
# 23  [ini, sahih, pembicaraan, soal, ice, cold, mem...
# 24  [jessica, haru, dapetin, keadilan, dan, apakah...
# 25  [tuh, bapaknya, mirna, knpa, makin, aneh, aja,...
# 26  [hidup, lg, tenang, dan, lurus, dibikin, kesel...
# 27  [jeropoint, taskyagn, wafdasaifan, teukurifnu,...
# 28  [netflix, extraction, ice, cold, murder, coffe...
# 29  [halo, yang, lagi, nyari, netflix, murah, buat...

# %% [markdown]
# ## 5. Filtering / Stopword Removal

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('indonesian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopwords(text):
  return [word for word in text if word not in stop_words]

df['filtering/stopword removal'] = df['tokenize'].apply(lambda x: remove_stopwords(x))

df.head(30)
# Out:
#                                             full_text  \
# 0   Haaii aku jual netflix 1 bulan sebulan 20k aja...
# 1   Terlepas apakah yang dilakukan Netflix dengan ...
# 2   Watched Ice Cold documentary on Netflix, the m...
# 3                      Ice Cold on Netflix is so good
# 4   https://t.co/dBHtffcYLr People who have alread...
# 5   lebih detailnya lagi setelah netflix #Icecoldn...
# 6   Penjelasan Dokter Ahli Sianida yang tampil dal...
# 7   And that's kid, is how your mother procrastina...
# 8   woi beli netflix dmn yg murce bokap gua mau no...
# 9   pgn beli Netflix lg buat nntn ice cold, soalny...
# 10  Selain “Ice Cold”, Ini Film Dokumenter Netflix...
# 11  🎬 ice cold: murder, coffee and jessica wongso ...
# 12  Tadi maghrib...aku yg lagi nyetrika sambil net...
# 13  Menghukum orang tanpa bukti yang sah. Ingat KA...
# 14  Abis nntn Icecold di netflix. Dulu aku sempet ...
# 15  Reco watch: Ice Cold: Murder, Coffee and Jessi...
# 16  btw cek profil kita ya yg mau nonton One Piece...
# 17  Setelah Netflix Tayangkan Dokumenter 'Ice Cold...
# 18  Adanya film ice cold netflix justru membahayak...
# 19  Udah jenuh banget di RS. Padahal bisa sambil N...
# 20  jangan lupa cuci mata sebelum tidur #JessicaWo...
# 21  belum lama nonton dokumenter ice cold, terus b...
# 22  Dari film Ice Cold yg sempat di putar di Netfl...
# 23  Ini sahih. Pembicaraan soal Ice Cold memang be...
# 21  belum lama nonton dokumenter ice cold terus bo...
# 22  dari film ice cold yg sempat di putar di netfl...
# 23  ini sahih pembicaraan soal ice cold memang bet...
# 24  jessica haru dapetin keadilan dan apakah kasus...
# 25  tuh bapaknya mirna knpa makin aneh aja ngomong...
# 26  hidup lg tenang dan lurus dibikin kesel sendir...
# 27  jeropoint taskyagn wafdasaifan teukurifnu mvpp...
# 28  netflix  extraction     ice cold murder coffee...
# 29  halo yang lagi nyari netflix murah buat nonton...
#
#                                              tokenize  \
# 0   [haaii, aku, jual, netflix, bulan, sebulan, k,...
# 1   [terlepas, apakah, yang, dilakukan, netflix, d...
# 2   [watched, ice, cold, documentary, on, netflix,...
# 3              [ice, cold, on, netflix, is, so, good]
# 4   [httpstcodbhtffcylr, people, who, have, alread...
# 5   [lebih, detailnya, lagi, setelah, netflix, ice...
# 6   [penjelasan, dokter, ahli, sianida, yang, tamp...
# 7   [and, thats, kid, is, how, your, mother, procr...
# 8   [woi, beli, netflix, dmn, yg, murce, bokap, gu...
# 9   [pgn, beli, netflix, lg, buat, nntn, ice, cold...
# 10  [selain, ice, cold, ini, film, dokumenter, net...
# 11  [ice, cold, murder, coffee, and, jessica, wong...
# 12  [tadi, maghribaku, yg, lagi, nyetrika, sambil,...
# 13  [menghukum, orang, tanpa, bukti, yang, sah, in...
# 14  [abis, nntn, icecold, di, netflix, dulu, aku, ...
# 15  [reco, watch, ice, cold, murder, coffee, and, ...
# 16  [btw, cek, profil, kita, ya, yg, mau, nonton, ...
# 17  [setelah, netflix, tayangkan, dokumenter, ice,...
# 18  [adanya, film, ice, cold, netflix, justru, mem...
# 19  [udah, jenuh, banget, di, rs, padahal, bisa, s...
# 20  [jangan, lupa, cuci, mata, sebelum, tidur, jes...
# 21  [belum, lama, nonton, dokumenter, ice, cold, t...
# 22  [dari, film, ice, cold, yg, sempat, di, putar,...
# 23  [ini, sahih, pembicaraan, soal, ice, cold, mem...
# 24  [jessica, haru, dapetin, keadilan, dan, apakah...
# 25  [tuh, bapaknya, mirna, knpa, makin, aneh, aja,...
# 26  [hidup, lg, tenang, dan, lurus, dibikin, kesel...
# 27  [jeropoint, taskyagn, wafdasaifan, teukurifnu,...
# 28  [netflix, extraction, ice, cold, murder, coffe...
# 29  [halo, yang, lagi, nyari, netflix, murah, buat...
#
#                            filtering/stopword removal
# 0   [haaii, jual, netflix, sebulan, k, aja, promo,...
# 1   [terlepas, netflix, menayangkan, film, dokumen...
# 2   [watched, ice, cold, documentary, on, netflix,...
# 3              [ice, cold, on, netflix, is, so, good]
# 4   [httpstcodbhtffcylr, people, who, have, alread...
# 5   [detailnya, netflix, icecoldnetflix, httpstcos...
# 6   [penjelasan, dokter, ahli, sianida, tampil, do...
# 7   [and, thats, kid, is, how, your, mother, procr...
# 8   [woi, beli, netflix, dmn, yg, murce, bokap, gu...
# 9   [pgn, beli, netflix, lg, nntn, ice, cold, fyp,...
# 10  [ice, cold, film, dokumenter, netflix, angkat,...
# 11  [ice, cold, murder, coffee, and, jessica, wong...
# 12  [maghribaku, yg, nyetrika, netflix, lantai, de...
# 13  [menghukum, orang, bukti, sah, karma, cepat, b...
# 14  [abis, nntn, icecold, netflix, sempet, ikutin,...
# 15  [reco, watch, ice, cold, murder, coffee, and, ...
# 16  [btw, cek, profil, ya, yg, nonton, one, piece,...
# 17  [netflix, tayangkan, dokumenter, ice, cold, ma...
# 18  [film, ice, cold, netflix, membahayakan, nyawa...
# 19  [udah, jenuh, banget, rs, netflix, blm, nonton...
# 20  [lupa, cuci, mata, tidur, jessicawongso, mirna...
# 21  [nonton, dokumenter, ice, cold, bokapnya, alm,...
# 22  [film, ice, cold, yg, putar, netflix, nonton, ...
# 23  [sahih, pembicaraan, ice, cold, menasional, ta...
# 24  [jessica, haru, dapetin, keadilan, ending, nya...
# 25  [tuh, bapaknya, mirna, knpa, aneh, aja, ngomon...
# 26  [hidup, lg, tenang, lurus, dibikin, kesel, geg...
# 27  [jeropoint, taskyagn, wafdasaifan, teukurifnu,...
# 28  [netflix, extraction, ice, cold, murder, coffe...
# 29  [halo, nyari, netflix, murah, nonton, ice, col...

# %% [markdown]
# ## 6. Steaming Data

# %%
# !pip install Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(text):
  return [stemmer.stem(word) for word in text]

df['stemming_data'] = df['filtering/stopword removal'].apply(lambda x: ' '.join(stem_text(x)))

df.head()
# Out:
#                                            full_text  \
# 0  Haaii aku jual netflix 1 bulan sebulan 20k aja...
# 1  Terlepas apakah yang dilakukan Netflix dengan ...
# 2  Watched Ice Cold documentary on Netflix, the m...
# 3                     Ice Cold on Netflix is so good
# 4  https://t.co/dBHtffcYLr People who have alread...
#
#                                             cleaning  \
# 0  Haaii aku jual netflix  bulan sebulan k aja la...
# 1  Terlepas apakah yang dilakukan Netflix dengan ...
# 2  Watched Ice Cold documentary on Netflix the mo...
# 3                     Ice Cold on Netflix is so good
# 4  httpstcodBHtffcYLr People who have already wat...
#
#                                         case_folding  \
# 0  haaii aku jual netflix  bulan sebulan k aja la...
# 1  terlepas apakah yang dilakukan netflix dengan ...
# 2  watched ice cold documentary on netflix the mo...
# 3                     ice cold on netflix is so good
# 4  httpstcodbhtffcylr people who have already wat...
#
#                                             tokenize  \
# 0  [haaii, aku, jual, netflix, bulan, sebulan, k,...
# 1  [terlepas, apakah, yang, dilakukan, netflix, d...
# 2  [watched, ice, cold, documentary, on, netflix,...
# 3             [ice, cold, on, netflix, is, so, good]
# 4  [httpstcodbhtffcylr, people, who, have, alread...
#
#                           filtering/stopword removal  \
# 0  [haaii, jual, netflix, sebulan, k, aja, promo,...
# 1  [terlepas, netflix, menayangkan, film, dokumen...
# 2  [watched, ice, cold, documentary, on, netflix,...
# 3             [ice, cold, on, netflix, is, so, good]
# 4  [httpstcodbhtffcylr, people, who, have, alread...
#
#                                        stemming_data
# 0  haaii jual netflix bulan k aja promo yuukk pu ...
# 1  lepas netflix tayang film dokumenter ice cold ...
# 2  watched ice cold documentary on netflix the mo...
# 3                     ice cold on netflix is so good
# 4  httpstcodbhtffcylr people who have already wat...

# %%
df.to_csv('Hasil_Preprocessing_Data.csv', encoding='utf8', index=False)
